# %% [markdown]
# # 3. 다중 특성과 복합적 관계 이해
#
# - `02_AI_Math_분석`에서 `과제 제출률`과 `시험 점수`사이에 0.48이라는 중간 정도의 상관관계를 확인하였음.
# - 이는 `과제 제출률` 만으로는 점수를 완벽하게 설명 할 수 없으며, 아직 고려하지 않은 특성이 있다는 의미.
#
# ## 3-1. 다중 특성과 음의 상관관계
#
# ### 3-1-1. 다중 특성(Multiple Features)
#
# - 하나의 **결과 변수**(Y)를 예측하기 위해 사용되는 **여러 개의 입력 변수**(X1, X2, X3 …)를 의미.
# - 현실의 문제는 대부분 여러 요인이 복합적으로 작용하여 발생
#
# ### 3-1-2. 음의 상과관계(Negative Correlation)
#
# - 두 변수가 서로 반대 방향으로 움직이는 경향을 보이는 관계
# - 즉, 한 변수의 값이 증가 할 때 다른 변수의 값은 감소하는 경향을 보임
# - 상관 계수로는 -1에 가까운 값으로 표현됨
#
# ## 3-2. 라인 플롯과 산점도를 이용한 다중 특성 분석
#
# - 난이도별 실습 제출률(sub_rate_d1 ~ sub_rate_d8)을 분석
#
# 1. 라인 플롯을 이용한 음의 상관관계 시각화
#     - 실습의 난이도가 평균 제출률에 어떤 영향을 미치는지 확인하기 위해 라인 플롯을 사용
#     - x축은 난이도, y축은 각 난이도별 제출률의 평균 값

# %%
# Google Drive 연결
from google.colab import drive
drive.mount('/content/drive')

base_path = '/content/drive/MyDrive/Colab Notebooks/'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 실습에 사용할 메인 데이터셋 로드
df_main = pd.read_csv(base_path + 'virtual_student_data.csv')

# 메인 데이터셋 정보 확인
print("Main Dataset Info:")
df_main.info()

# %%
# 1. 8개 난이도별 실습 제출률 컬럼만 선택
submission_cols = [f'sub_rate_d{i+1}' for i in range(8)]
# print(submission_cols)
difficulty_df = df_main[submission_cols]
print(difficulty_df.head())

# %%
# 2. 각 난이도별 평균 제출률 계산
mean_submission_rates = difficulty_df.mean()

# 3. 라인 플롯 그리기
plt.figure(figsize=(10, 6))
# plot 함수로 라인 플롯 생성
    # x축: 난이도 (1~8), y축: 평균 제출률
    # marker: 데이터 포인트 표시 스타일
    # linestyle: 선 스타일
plt.plot(range(1, 9), mean_submission_rates, marker='o', linestyle='--')

# 4. 그래프에 제목과 라벨 추가
plt.title('Average Submission Rate by Difficulty Level')
plt.xlabel('Difficulty Level')
plt.ylabel('Average Submission Rate (%)')
plt.grid(True)
plt.show()

# %% [markdown]
# 2. 산점도를 이용한 특성별 중요도 비교
#     - 가장 쉬운 난이도(d1)의 제출률과 가장 어려운 난이도(d8)의 제출률이 각각 '시험 점수'와 어떤 관계를 맺고 있는지 산점도로 비교
#     - 특성별 영향력이 다를 수 있음을 확인

# %%
# 1. 비교할 세 특성과 결과 변수 선택
assign_ment_rate = df_main['assignment_rate']
sub_rate_d1 = df_main['sub_rate_d1']
sub_rate_d8 = df_main['sub_rate_d8']
final_score = df_main['final_score']

# 2. 두 개의 산점도를 나란히 그리기
    # subplots 함수로 1행 2열의 서브플롯 생성
    # output: 1행 2열의 서브플롯이 있는 Figure 객체와 각 서브플롯에 대한 Axes 객체 반환
        # Figure: 전체 그래프 영역
        # Axes: 실제 데이터가 그려지는 영역
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 6)) # 1행 3열의 서브플롯 생성

# 과제 제출률 산점도
ax1.scatter(assign_ment_rate, final_score, alpha=0.5, color='red')
ax1.set_title('Assignment Rate vs. Final Score')
ax1.set_xlabel('Assignment Rate (%)')
ax1.set_ylabel('Final Exam Score')
ax1.grid(True)

# 가장 쉬운 난이도(d1) 산점도
ax2.scatter(sub_rate_d1, final_score, alpha=0.5)
ax2.set_title('Difficulty 1 Rate vs. Final Score')
ax2.set_xlabel('Submission Rate for Difficulty 1 (%)')
ax2.set_ylabel('Final Exam Score')
ax2.grid(True)

# 가장 어려운 난이도(d8) 산점도
ax3.scatter(sub_rate_d8, final_score, alpha=0.5, color='green')
ax3.set_title('Difficulty 8 Rate vs. Final Score')
ax3.set_xlabel('Submission Rate for Difficulty 8 (%)')
ax3.set_ylabel('Final Exam Score')
ax3.grid(True)

plt.tight_layout() # 그래프 간격 자동 조절
plt.show()

# %% [markdown]
# ## 3-3. **분석 결과**
#
# 1. 난이도가 높아질수록 평균 제출률이 감소하는 명확한 우하향 패턴. **음의 상관관계**를 보여줌
# 2. 두 산점도를 비교했을 때, 가장 어려운 난이도(d8)의 제출률이 시험 점수와 더 뚜렷한 양의 상관관계를 보일 수 있음
# 3. 그러나, 여전히 명확히 얼마나 큰 영향력인지는 알기 어려움
#
# ## 3-4. 상관 계수 비교 분석
#
# ### 3-4-1. 비교 분석
#
# - 모든 특성이 똑같이 중요하지는 않음.
# - 특정 특성은 결과에 결정적인 역할을 하고, 어떤 특성은 부수적인 정보만 제공
# - 따라서, **핵심 특성**을 찾아내는 것이 매우 중요
#
# ### 3-4-2. 상관 계수 계산 및 막대그래프 시각화
#
# 1. 여러 입력 특성 각각이 결과 변수와 갖는 상관 계수를 모두 계산
# 2. 어떤 특성이 점수를 예측하는데 더 강력한 `설명력`을 갖는지 객관적으로 비교
#     - 막대그래프 (Bar Plot)을 이용한 시각적 비교

# %%
# 1. 분석할 모든 제출률 관련 컬럼 리스트 생성
submission_cols = ['assignment_rate'] + [f'sub_rate_d{i+1}' for i in range(8)]

# 2. 각 특성과 final_score 간의 상관 계수만 계산하여 Series로 저장
correlations = df_main[submission_cols + ['final_score']].corr()['final_score']

# final_score 자기 자신과의 상관관계(1.0)는 제외
correlations = correlations.drop('final_score')

# 3. 상관 계수를 내림차순으로 정렬
correlations_sorted = correlations.sort_values(ascending=False)

print("Correlation with Final Score (Sorted):")
print(correlations_sorted)

# 4. 막대그래프로 시각화
plt.figure(figsize=(12, 7))
correlations_sorted.plot(kind='bar', color='skyblue', edgecolor='black')

# 5. 그래프에 제목과 라벨 추가
plt.title('Correlation of Various Submission Rates with Final Score', fontsize=15)
plt.xlabel('Submission Rate Feature', fontsize=12)
plt.ylabel('Correlation Coefficient', fontsize=12)
plt.xticks(rotation=45, ha='right') # x축 라벨이 겹치지 않도록 회전
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3-5. 최종 분석 결과
#
# 1. 상관 계수를 정량적으로 분석한 결과, `final_score`와 가장 높은 상관관계를 보이는 특성은 **가장 낮은 난이도의 실습 제출률(`sub_rate_d1`)**
# 2. 난이도가 높아질수록 상관 계수는 점진적으로 감소하는 경향
# 3. 그럼에도, 과제 제츌률보다는 높은 계수임을 확인 할 수 있음.
# - 각 특성은 결과 변수와 서로 다른 강도의 관계를 맺고 있으며, 하나의 특성만으로는 전체를 설명할 수 없음
