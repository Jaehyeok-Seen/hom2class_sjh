# %% [markdown]
# # 0. 들어가기 전에
#
# ## 0-1. AI 이론.. 너무 어렵다!!
#
# - 진짜 너무 어렵다….
# - 하지만 괜찮다!
# - 사실 web 과정에서 학습하고 있는 web server 개발도, 정말 모오든 과정을 내가 다 만든다고 한다면… 어쩌면 어제 배운 AI 이론 보다 어려울 수도 있다. 그만큼 광범위 하니까!
# - 그럼 우리는 어떻게 해야 할까…? 그래서! django framework를 사용한다.
#
# ## 0-2. 코드 맛보기
#
# - 어제 배운 방법 중, 선형 회귀를 해보고 싶다면?
# - 이미 잘 만들어진 `선형 회귀 모델`을 사용하자.
#
# ### 0-2-1. 데이터 불러오기

# %%
# 필요한 라이브러리 임포트
# 1. 데이터셋 로드

# 2. 데이터 분리


# 데이터 셋 로드
df, y = load_wine(return_X_y=True, as_frame=True)

# 훈련용 데이터와 테스트 데이터를 분리
print(X_train.shape, X_test.shape)   # (142, 13) (36, 13)

# %% [markdown]
# ### 0-2-2. 선형 회귀 모델 훈련
# - 잘 만들어진 모델을 내가 가진 데이터에 맞춰(fit) 학습 시키고,
# - 모델이 잘 학습했는지, 테스트용 데이터로 예측 해보기

# %%
# 필요한 라이브러리 임포트


# 인스턴스 생성

# 선형 회귀 모델 훈련

# 테스트 데이터로 예측 수행

# 예측 결과 출력
print(y_pred)   # 예측된 타겟 벡터
print(y_test.values)  # 실제 타겟 벡터

# %% [markdown]
# ### 0-2-3. 내 모델이 잘 학습했는지 평가하기

# %%
# 모델 평가 / 평균 제곱 오차 (MSE), 결정 계수 (R²)


# 평균 제곱 오차가 0에 가까울수록 좋은 모델

print(mse) # 평균 제곱 오차

# 결정 계수가 1에 가까울수록 좋은 모델

print(r2)  # 결정 계수

# 테스트 데이터에 대한 R² 점수

print(model_score)  # 모델 점수 (R²)
